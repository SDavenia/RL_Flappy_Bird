# %% [markdown]
# # Expected SARSA
# Will write to a file Summary/Exp_SARSA_summary with this format
# k_alpha, k_epsilon, mean, median standard deviation

# %%
import re
def extract_parameters_EXP_SARSA(file_name):
    """
    - WRITTEN WITH HELP FROM CHATGPT - 
    Extracts parameters from the expected SARSA title object.
    We only have two parameters to extact, k_alpha and k_epsilon
    """
    # Extracting the 'k' parameter
    k_alpha_match = re.search(r'(?<=k_alpha_)[\d.e-]+', file_name)
    k_alpha = k_alpha_match.group() if k_alpha_match else None

    # Extracting the 'alpha' parameter


    # Extracting the 'epsilon' parameter
    k_epsilon_match = re.search(r'(?<=k_epsilon)[\d.e-]+', file_name)
    k_epsilon = float(k_epsilon_match.group()[:-1]) if k_epsilon_match else None

    # Print the extracted parameters
    print(f"k_alpha: {k_alpha}")
    print(f"epsilon: {k_epsilon}")
    return float(k_alpha), float(k_epsilon)

# See if it works
file_name = "Exp_SARSA_k_alpha_0.03k_epsilon0.05.txt" # WORKS ON EXPECTED SARSA
extract_parameters_EXP_SARSA(file_name)
# Out:
# k_alpha: 0.03
# epsilon: 0.05
# (0.03, 0.05)

# %%
#- WRITTEN WITH HELP FROM CHATGPT - 
import os 
import numpy as np
# Specify the folder path EXP_SARSA
folder_path = "Trajectories/Exp_SARSA_trajectories"

# Target directory to store the summary.
# It is stored with this form:
# k_alpha, k_epsilon, mu, med, sd
target_file = "Summary/Exp_SARSA_summary" # File where we want to append the results

# To delete the previous one if already existing.
with open(target_file, 'w') as t_file:
    pass 

# Loop over all files in the folder
for file_name in os.listdir(folder_path):
    # Now we scan all the files
    if file_name.endswith('.txt'):
        # Construct the full file path
        file_path = os.path.join(folder_path, file_name)
        k_alpha, k_epsilon = extract_parameters_EXP_SARSA(file_name)
        # Perform operations on the file
        with open(file_path, 'r') as file:
            # Read the contents of the file
            #print(f"File: {file_name}")
            data = np.loadtxt(file_path)
            data = data[-1000:]
            mu = np.mean(data)
            med = np.median(data)
            sd = np.std(data)
        with open(target_file, 'a') as t_file:
            t_file.write(str(k_alpha) + " " + str(k_epsilon) + " " + str(mu) + " " + str(med) + " " + str(sd) + "\n")
# Out:
# k_alpha: 0
# epsilon: 0.0
# k_alpha: 0.03
# epsilon: 0.005
# k_alpha: 3e-05
# epsilon: 5e-05
# k_alpha: 0.003
# epsilon: 0.05
# k_alpha: 0.0003
# epsilon: 0.0005
# k_alpha: 0.03
# epsilon: 0.05
# k_alpha: 3e-05
# epsilon: 0.05
# k_alpha: 0.03
# epsilon: 5e-05
# k_alpha: 3e-05
# epsilon: 0.005
# k_alpha: 0.003
# epsilon: 5e-05
# k_alpha: 3e-05
# epsilon: 0.0005
# k_alpha: 0.0003
# epsilon: 5e-05
# k_alpha: 0.0003
# epsilon: 0.05
# k_alpha: 0.03
# epsilon: 0.0005
# k_alpha: 0.003
# epsilon: 0.005
# k_alpha: 0.003
# epsilon: 0.0005
# k_alpha: 0.0003
# epsilon: 0.005

# %% [markdown]
# # SARSA and Q-Leearning
# Will write to a file with the following standard:
# lambda_, k_alpha, k_epsilon, mean, median, std

# %%
def extract_parameters_SARSA_Q(file_name):
    #- WRITTEN WITH HELP FROM CHATGPT - 
    # Extracting the 'k_alpha' parameter
    k_alpha_match = re.search(r'(?<=k_alpha_)[\d.e-]+', file_name)
    k_alpha = k_alpha_match.group() if k_alpha_match else None

    # Extracting lambda parameter
    lambda_match = re.search(r'(?<=lambda_)[\d.e-]+', file_name)
    lambda_ = lambda_match.group() if lambda_match else None

    # Extracting the 'k_epsilon' parameter
    k_epsilon_match = re.search(r'(?<=k_epsilon)[\d.e-]+', file_name)
    k_epsilon = float(k_epsilon_match.group()[:-1]) if k_epsilon_match else None

    # Print the extracted parameters
    print(f"lambda: {lambda_}")
    print(f"k_alpha: {k_alpha}")
    print(f"k_epsilon: {k_epsilon}")
    return float(lambda_), float(k_alpha), float(k_epsilon)

# See if it works
file_name = "SARSA_lambda_0.5_k_alpha_3e-05k_epsilon5e-05.txt"
extract_parameters_SARSA_Q(file_name)
# Out:
# lambda: 0.5
# k_alpha: 3e-05
# k_epsilon: 5e-05
# (0.5, 3e-05, 5e-05)

# %%
# - WRITTEN WITH HELP FROM CHATGPT - 
# Specify the folder path SARSA!
folder_path = "Trajectories/SARSA_trajectories"

# Target directory to store the summary.
# It is stored with this form:
# k_alpha, k_epsilon, mu, med, sd
target_file = "Summary/SARSA_summary" # File where we want to append the results

# To delete the previous one if already existing.
with open(target_file, 'w') as t_file:
    pass 

# Loop over all files in the folder
for file_name in os.listdir(folder_path):
    # Now we scan all the files
    if file_name.endswith('.txt'):
        # Construct the full file path
        file_path = os.path.join(folder_path, file_name)
        lambda_, k_alpha, k_epsilon = extract_parameters_SARSA_Q(file_name)
        # Perform operations on the file
        with open(file_path, 'r') as file:
            # Read the contents of the file
            #print(f"File: {file_name}")
            data = np.loadtxt(file_path)
            data = data[-1000:]
            mu = np.mean(data)
            med = np.median(data)
            sd = np.std(data)
        with open(target_file, 'a') as t_file:
            t_file.write(str(lambda_) + " " + str(k_alpha) + " " + str(k_epsilon) + " " + str(mu) + " " + str(med) + " " + str(sd) + "\n")
# Out:
# lambda: 0.0
# k_alpha: 0.03
# k_epsilon: 5e-05
# lambda: 0.5
# k_alpha: 0.0003
# k_epsilon: 0.05
# lambda: 0.5
# k_alpha: 0.03
# k_epsilon: 0.0005
# lambda: 0.5
# k_alpha: 0.003
# k_epsilon: 0.005
# lambda: 0.2
# k_alpha: 0.003
# k_epsilon: 0.0005
# lambda: 0.0
# k_alpha: 0.0003
# k_epsilon: 0.05
# lambda: 0.0
# k_alpha: 0.03
# k_epsilon: 0.0005
# lambda: 0.0
# k_alpha: 3e-05
# k_epsilon: 0.05
# lambda: 0.0
# k_alpha: 0.003
# k_epsilon: 0.005
# lambda: 0.2
# k_alpha: 0.0003
# k_epsilon: 0.005
# lambda: 0.2
# k_alpha: 3e-05
# k_epsilon: 0.005
# lambda: 0.8
# k_alpha: 0.0003
# k_epsilon: 0.05
# lambda: 0.8
# k_alpha: 0.03
# k_epsilon: 0.0005
# lambda: 0.5
# k_alpha: 0.0003
# k_epsilon: 5e-05
# lambda: 0.0
# k_alpha: 0
# k_epsilon: 0.0
# lambda: 0.8
# k_alpha: 0.003
# k_epsilon: 0.005
# lambda: 0.5
# k_alpha: 3e-05
# k_epsilon: 0.0005
# lambda: 0.2
# k_alpha: 3e-05
# k_epsilon: 0.0005
# lambda: 0.0
# k_alpha: 0.003
# k_epsilon: 5e-05
# lambda: 0.8
# k_alpha: 0.03
# k_epsilon: 0.05
# lambda: 0.2
# k_alpha: 0.0003
# k_epsilon: 5e-05
# lambda: 0.0
# k_alpha: 0.03
# k_epsilon: 0.005
# lambda: 0.5
# k_alpha: 0.003
# k_epsilon: 5e-05
# lambda: 0.0
# k_alpha: 0.003
# k_epsilon: 0.05
# lambda: 0.2
# k_alpha: 0.0003
# k_epsilon: 0.0005
# lambda: 0.0
# k_alpha: 0.0003
# k_epsilon: 0.0005
# lambda: 0.5
# k_alpha: 0.0003
# k_epsilon: 0.005
# lambda: 0.8
# k_alpha: 0.003
# k_epsilon: 5e-05
# lambda: 0.5
# k_alpha: 0.003
# k_epsilon: 0.0005
# lambda: 0.8
# k_alpha: 0
# k_epsilon: 0.0
# lambda: 0.2
# k_alpha: 3e-05
# k_epsilon: 5e-05
# lambda: 0.0
# k_alpha: 0.03
# k_epsilon: 0.05
# lambda: 0.2
# k_alpha: 3e-05
# k_epsilon: 0.05
# lambda: 0.5
# k_alpha: 3e-05
# k_epsilon: 0.005
# lambda: 0.5
# k_alpha: 0.03
# k_epsilon: 0.005
# lambda: 0.5
# k_alpha: 0.003
# k_epsilon: 0.05
# lambda: 0.8
# k_alpha: 0.03
# k_epsilon: 5e-05
# lambda: 0.2
# k_alpha: 0.03
# k_epsilon: 5e-05
# lambda: 0.0
# k_alpha: 3e-05
# k_epsilon: 0.0005
# lambda: 0.0
# k_alpha: 3e-05
# k_epsilon: 0.005
# lambda: 0.0
# k_alpha: 0.0003
# k_epsilon: 5e-05
# lambda: 0.8
# k_alpha: 3e-05
# k_epsilon: 0.05
# lambda: 0.2
# k_alpha: 0.003
# k_epsilon: 0.005
# lambda: 0.8
# k_alpha: 0.0003
# k_epsilon: 5e-05
# lambda: 0.8
# k_alpha: 3e-05
# k_epsilon: 0.0005
# lambda: 0.2
# k_alpha: 0.0003
# k_epsilon: 0.05
# lambda: 0.5
# k_alpha: 0
# k_epsilon: 0.0
# lambda: 0.2
# k_alpha: 0.03
# k_epsilon: 0.0005
# lambda: 0.8
# k_alpha: 3e-05
# k_epsilon: 0.005
# lambda: 0.5
# k_alpha: 3e-05
# k_epsilon: 0.05
# lambda: 0.2
# k_alpha: 0.03
# k_epsilon: 0.005
# lambda: 0.2
# k_alpha: 0.03
# k_epsilon: 0.05
# lambda: 0.0
# k_alpha: 0.003
# k_epsilon: 0.0005
# lambda: 0.0
# k_alpha: 3e-05
# k_epsilon: 5e-05
# lambda: 0.0
# k_alpha: 0.0003
# k_epsilon: 0.005
# lambda: 0.2
# k_alpha: 0.003
# k_epsilon: 0.05
# lambda: 0.5
# k_alpha: 0.03
# k_epsilon: 5e-05
# lambda: 0.8
# k_alpha: 0.003
# k_epsilon: 0.05
# lambda: 0.5
# k_alpha: 3e-05
# k_epsilon: 5e-05
# lambda: 0.8
# k_alpha: 0.03
# k_epsilon: 0.005
# lambda: 0.5
# k_alpha: 0.03
# k_epsilon: 0.05
# lambda: 0.8
# k_alpha: 3e-05
# k_epsilon: 5e-05
# lambda: 0.5
# k_alpha: 0.0003
# k_epsilon: 0.0005
# lambda: 0.2
# k_alpha: 0.003
# k_epsilon: 5e-05
# lambda: 0.8
# k_alpha: 0.0003
# k_epsilon: 0.0005
# lambda: 0.8
# k_alpha: 0.0003
# k_epsilon: 0.005
# lambda: 0.2
# k_alpha: 0
# k_epsilon: 0.0
# lambda: 0.8
# k_alpha: 0.003
# k_epsilon: 0.0005

# %%
# - WRITTEN WITH HELP FROM CHATGPT - 
# Specify the folder path Q LEARNING
folder_path = "Trajectories/Q_trajectories"

# Target directory to store the summary.
# It is stored with this form:
# k_alpha, k_epsilon, mu, med, sd
target_file = "Summary/Q_summary" # File where we want to append the results

# To delete the previous one if already existing.
with open(target_file, 'w') as t_file:
    pass 

# Loop over all files in the folder
for file_name in os.listdir(folder_path):
    # Now we scan all the files
    if file_name.endswith('.txt'):
        # Construct the full file path
        file_path = os.path.join(folder_path, file_name)
        lambda_, k_alpha, k_epsilon = extract_parameters_SARSA_Q(file_name)
        # Perform operations on the file
        with open(file_path, 'r') as file:
            # Read the contents of the file
            #print(f"File: {file_name}")
            data = np.loadtxt(file_path)
            data = data[-1000:]
            mu = np.mean(data)
            med = np.median(data)
            sd = np.std(data)
        with open(target_file, 'a') as t_file:
            t_file.write(str(lambda_) + " " + str(k_alpha) + " " + str(k_epsilon) + " " + str(mu) + " " + str(med) + " " + str(sd) + "\n")
# Out:
# lambda: 0.8
# k_alpha: 0.0003
# k_epsilon: 0.05
# lambda: 0.2
# k_alpha: 0.03
# k_epsilon: 0.05
# lambda: 0.8
# k_alpha: 0.03
# k_epsilon: 0.0005
# lambda: 0.5
# k_alpha: 0.0003
# k_epsilon: 5e-05
# lambda: 0.2
# k_alpha: 0
# k_epsilon: 0.0
# lambda: 0.8
# k_alpha: 0.003
# k_epsilon: 0.005
# lambda: 0.5
# k_alpha: 3e-05
# k_epsilon: 0.0005
# lambda: 0.0
# k_alpha: 0.0003
# k_epsilon: 0.0005
# lambda: 0.2
# k_alpha: 3e-05
# k_epsilon: 0.005
# lambda: 0.8
# k_alpha: 0.03
# k_epsilon: 5e-05
# lambda: 0.2
# k_alpha: 0.003
# k_epsilon: 0.0005
# lambda: 0.5
# k_alpha: 0.003
# k_epsilon: 0.05
# lambda: 0.5
# k_alpha: 0.03
# k_epsilon: 0.05
# lambda: 0.0
# k_alpha: 0.0003
# k_epsilon: 0.05
# lambda: 0.0
# k_alpha: 0.03
# k_epsilon: 0.0005
# lambda: 0.0
# k_alpha: 0.003
# k_epsilon: 0.005
# lambda: 0.2
# k_alpha: 0.0003
# k_epsilon: 0.0005
# lambda: 0.2
# k_alpha: 0.0003
# k_epsilon: 0.005
# lambda: 0.2
# k_alpha: 3e-05
# k_epsilon: 0.05
# lambda: 0.5
# k_alpha: 0.03
# k_epsilon: 0.005
# lambda: 0.5
# k_alpha: 0.0003
# k_epsilon: 0.05
# lambda: 0.8
# k_alpha: 3e-05
# k_epsilon: 0.05
# lambda: 0.5
# k_alpha: 0.03
# k_epsilon: 0.0005
# lambda: 0.5
# k_alpha: 0.003
# k_epsilon: 0.005
# lambda: 0.2
# k_alpha: 0.03
# k_epsilon: 5e-05
# lambda: 0.2
# k_alpha: 3e-05
# k_epsilon: 5e-05
# lambda: 0.5
# k_alpha: 0
# k_epsilon: 0.0
# lambda: 0.5
# k_alpha: 0.0003
# k_epsilon: 0.005
# lambda: 0.5
# k_alpha: 0.003
# k_epsilon: 0.0005
# lambda: 0.8
# k_alpha: 0.003
# k_epsilon: 5e-05
# lambda: 0.2
# k_alpha: 0.003
# k_epsilon: 0.05
# lambda: 0.5
# k_alpha: 0.003
# k_epsilon: 5e-05
# lambda: 0.5
# k_alpha: 3e-05
# k_epsilon: 0.05
# lambda: 0.2
# k_alpha: 0.03
# k_epsilon: 0.005
# lambda: 0.8
# k_alpha: 0.03
# k_epsilon: 0.005
# lambda: 0.2
# k_alpha: 3e-05
# k_epsilon: 0.0005
# lambda: 0.0
# k_alpha: 0.003
# k_epsilon: 5e-05
# lambda: 0.2
# k_alpha: 0.0003
# k_epsilon: 5e-05
# lambda: 0.8
# k_alpha: 0.003
# k_epsilon: 0.05
# lambda: 0.5
# k_alpha: 0.03
# k_epsilon: 5e-05
# lambda: 0.8
# k_alpha: 0.0003
# k_epsilon: 0.0005
# lambda: 0.8
# k_alpha: 3e-05
# k_epsilon: 0.005
# lambda: 0.8
# k_alpha: 0.03
# k_epsilon: 0.05
# lambda: 0.8
# k_alpha: 0.0003
# k_epsilon: 5e-05
# lambda: 0.8
# k_alpha: 0
# k_epsilon: 0.0
# lambda: 0.2
# k_alpha: 0.003
# k_epsilon: 0.005
# lambda: 0.5
# k_alpha: 0.0003
# k_epsilon: 0.0005
# lambda: 0.2
# k_alpha: 0.0003
# k_epsilon: 0.05
# lambda: 0.8
# k_alpha: 3e-05
# k_epsilon: 0.0005
# lambda: 0.2
# k_alpha: 0.03
# k_epsilon: 0.0005
# lambda: 0.0
# k_alpha: 3e-05
# k_epsilon: 0.0005
# lambda: 0.0
# k_alpha: 3e-05
# k_epsilon: 0.005
# lambda: 0.0
# k_alpha: 0.03
# k_epsilon: 5e-05
# lambda: 0.0
# k_alpha: 0.0003
# k_epsilon: 5e-05
# lambda: 0.5
# k_alpha: 3e-05
# k_epsilon: 0.005
# lambda: 0.0
# k_alpha: 0.03
# k_epsilon: 0.05
# lambda: 0.0
# k_alpha: 3e-05
# k_epsilon: 0.05
# lambda: 0.8
# k_alpha: 0.0003
# k_epsilon: 0.005
# lambda: 0.2
# k_alpha: 0.003
# k_epsilon: 5e-05
# lambda: 0.0
# k_alpha: 0
# k_epsilon: 0.0
# lambda: 0.8
# k_alpha: 0.003
# k_epsilon: 0.0005
# lambda: 0.8
# k_alpha: 3e-05
# k_epsilon: 5e-05
# lambda: 0.5
# k_alpha: 3e-05
# k_epsilon: 5e-05
# lambda: 0.0
# k_alpha: 3e-05
# k_epsilon: 5e-05
# lambda: 0.0
# k_alpha: 0.003
# k_epsilon: 0.0005
# lambda: 0.0
# k_alpha: 0.003
# k_epsilon: 0.05
# lambda: 0.0
# k_alpha: 0.03
# k_epsilon: 0.005
# lambda: 0.0
# k_alpha: 0.0003
# k_epsilon: 0.005

# %% [markdown]
# # MC
# file contiene solo k_epsilon mu, med, std

# %%
def extract_parameters_MC(file_name):
    """
    # - WRITTEN WITH HELP FROM CHATGPT - 
    Extracts parameters from the expected SARSA.
    We only have two parameters to extact, k_alpha and k_epsilon
    - WRITTEN USING CHATGPT - 
    """

    # Extracting the 'epsilon' parameter
    k_epsilon_match = re.search(r'(?<=k_epsilon)[\d.e-]+', file_name)
    k_epsilon = float(k_epsilon_match.group()[:-1]) if k_epsilon_match else None

    # Print the extracted parameters
    #print(f"epsilon: {k_epsilon}")
    return float(k_epsilon)

# See if it works
file_name = "MC_k_epsilon0.0005.txt"
extract_parameters_MC(file_name)
# Out:
# 0.0005

# %%
# - WRITTEN WITH HELP FROM CHATGPT - 
# Specify the folder path EXP_SARSA
folder_path = "Trajectories/MC_trajectories"

# Target directory to store the summary.
# It is stored with this form:
# k_alpha, k_epsilon, mu, med, sd
target_file = "Summary/MC_summary" # File where we want to append the results

# To delete the previous one if already existing.
with open(target_file, 'w') as t_file:
    pass 

# Loop over all files in the folder
for file_name in os.listdir(folder_path):
    # Now we scan all the files
    if file_name.endswith('.txt'):
        # Construct the full file path
        file_path = os.path.join(folder_path, file_name)
        k_epsilon = extract_parameters_MC(file_name)
        # Perform operations on the file
        with open(file_path, 'r') as file:
            # Read the contents of the file
            #print(f"File: {file_name}")
            data = np.loadtxt(file_path)
            data = data[-1000:]
            mu = np.mean(data)
            med = np.median(data)
            sd = np.std(data)
        with open(target_file, 'a') as t_file:
            t_file.write(str(k_epsilon) + " " + str(mu) + " " + str(med) + " " + str(sd) + "\n")

# %% [markdown]
# # Analysis of RESULTS
# ## SARSA / Q_Learning

# %%
import pandas as pd

file_path = "Summary/SARSA_summary" # FOR SARSA

# Read the text file into a DataFrame
df = pd.read_csv(file_path, delimiter=' ', header=None)

# Print the DataFrame
print(df)
# Out:
#       0       1        2        3      4           5
# 0   0.0  0.0300  0.00005   76.691   59.0   67.435165
# 1   0.5  0.0003  0.05000  437.404  308.0  408.309731
# 2   0.5  0.0300  0.00050   88.491   70.0   67.123244
# 3   0.5  0.0030  0.00500  216.879  148.5  198.249389
# 4   0.2  0.0030  0.00050   90.942   66.0   77.204084
# ..  ...     ...      ...      ...    ...         ...
# 63  0.2  0.0030  0.00005  791.982  553.0  748.470572
# 64  0.8  0.0003  0.00050  421.805  303.0  374.573898
# 65  0.8  0.0003  0.00500  269.070  193.0  243.143322
# 66  0.2  0.0000  0.00000   58.011   43.0   51.595842
# 67  0.8  0.0030  0.00050  453.008  314.5  433.522262
#
# [68 rows x 6 columns]

# %%
file_path = "Summary/Q_summary" # FOR SARSA

# Read the text file into a DataFrame
df = pd.read_csv(file_path, delimiter=' ', header=None)

# Print the DataFrame
print(df)
# Out:
#       0        1        2         3       4            5
# 0   0.8  0.00030  0.05000  3595.010  2482.5  3684.509191
# 1   0.2  0.03000  0.05000    46.793    38.0    29.864095
# 2   0.8  0.03000  0.00050   340.300   253.0   282.606281
# 3   0.5  0.00030  0.00005   172.317   131.0   144.077037
# 4   0.2  0.00000  0.00000    52.598    41.5    46.253177
# ..  ...      ...      ...       ...     ...          ...
# 63  0.0  0.00003  0.00005  2989.408  2004.5  3071.134308
# 64  0.0  0.00300  0.00050   175.917   123.0   153.672555
# 65  0.0  0.00300  0.05000    80.352    63.0    62.613833
# 66  0.0  0.03000  0.00500   186.116   131.0   176.219898
# 67  0.0  0.00030  0.00500    49.111    43.0    29.886062
#
# [68 rows x 6 columns]

# %%
df.columns = ["lambda_", "k_alpha", "k_epsilon", "mean", "median", "sd"]
df.sort_values('mean', ascending=False)
# Out:
#     lambda_  k_alpha  k_epsilon      mean  median           sd
# 62      0.5  0.00003    0.00005  4783.610  3186.0  4952.148230
# 61      0.8  0.00003    0.00005  3624.031  2343.0  3996.748732
# 0       0.8  0.00030    0.05000  3595.010  2482.5  3684.509191
# 63      0.0  0.00003    0.00005  2989.408  2004.5  3071.134308
# 43      0.8  0.00030    0.00005  2462.887  1660.0  2481.273004
# ..      ...      ...        ...       ...     ...          ...
# 4       0.2  0.00000    0.00000    52.598    41.5    46.253177
# 59      0.0  0.00000    0.00000    51.494    36.5    46.329688
# 44      0.8  0.00000    0.00000    51.297    34.0    43.372581
# 67      0.0  0.00030    0.00500    49.111    43.0    29.886062
# 1       0.2  0.03000    0.05000    46.793    38.0    29.864095
#
# [68 rows x 6 columns]

# %% [markdown]
# ## Expected SARSA

# %%
file_path = "Summary/Exp_SARSA_summary" # FOR SARSA

# Read the text file into a DataFrame
df = pd.read_csv(file_path, delimiter=' ', header=None)


df.columns = ["k_alpha", "k_epsilon", "mean", "median", "sd"]
df.sort_values('mean', ascending=False)
# Out:
#     k_alpha  k_epsilon     mean  median          sd
# 11  0.00030    0.00005  127.305    93.0  111.714001
# 1   0.03000    0.00500  122.280    93.0   97.512961
# 16  0.00030    0.00500  105.501    73.0  101.061734
# 14  0.00300    0.00500   77.693    57.0   64.672009
# 2   0.00003    0.00005   70.235    53.0   56.271234
# 15  0.00300    0.00050   69.928    53.0   56.139672
# 13  0.03000    0.00050   68.440    50.0   55.853061
# 4   0.00030    0.00050   68.149    53.0   56.845798
# 10  0.00003    0.00050   62.359    46.0   52.975580
# 12  0.00030    0.05000   55.847    42.0   51.682391
# 0   0.00000    0.00000   49.982    35.0   42.942213
# 3   0.00300    0.05000   46.173    36.0   31.712412
# 5   0.03000    0.05000   39.014    33.0   29.767294
# 9   0.00300    0.00005   36.391    27.0   29.010035
# 7   0.03000    0.00005   23.479    23.0   12.422945
# 6   0.00003    0.05000   23.342    23.0   10.888298
# 8   0.00003    0.00500   21.181    13.0   13.868967

# %% [markdown]
# ## MC Methods

# %%
file_path = "Summary/MC_summary" # FOR SARSA

# Read the text file into a DataFrame
df = pd.read_csv(file_path, delimiter=' ', header=None)


df.columns = ["k_epsilon", "mean", "median", "sd"]
df.sort_values('mean', ascending=False)
# Out:
#    k_epsilon     mean  median          sd
# 2    0.00500  199.460   143.0  175.705630
# 3    0.00050  138.655   100.5  121.950547
# 0    0.05000  123.642    93.0  102.413084
# 4    0.00005  101.278    75.5   87.256603
# 1    0.00000   48.743    36.5   38.674578
